# %% [markdown]
# # Tennesee Eastman Process Data
# > Module for getting Tennesee Eastman Process data

# %%
#| default_exp TEP

# %%
from dPCA.lag import *
from dPCA.corrmat import *

# %%
#| export
#| hide
import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %% [markdown]
# We are now going to try and automate the analysis of PACM and ACM by simply utilising loops and eigenvalues. First however we are going to bring in some data from the Tennesee Eastman Process (TEP).

# %%
filepath = 'https://github.com/waterboy96/TEPData/blob/1ac08a54cb9d420ff4bc0c3f0076ca06dc2ec7e4/TEP.csv?raw=true'

# %%
TEP = pd.read_csv(filepath, index_col = [0]); TEP.head()
# Out:
#          0       1       2       3       4       5       6       7       8  \
# 0  0.24889  3702.3  4502.7  9.4170  26.996  42.183  2705.2  75.173  120.40
# 1  0.24904  3666.2  4526.0  9.2682  26.710  42.332  2705.5  74.411  120.41
# 2  0.25034  3673.3  4501.3  9.4212  26.842  42.360  2705.3  75.125  120.41
# 3  0.25109  3657.8  4497.8  9.3792  26.528  41.982  2707.3  73.992  120.38
# 4  0.24563  3698.0  4537.4  9.3746  26.736  42.354  2705.3  75.283  120.42
#
#          9  ...      42      43      44      45      46      47      48  \
# 0  0.33611  ...  54.059  24.804  63.269  21.950  40.188  39.461  47.000
# 1  0.33676  ...  53.781  24.790  62.171  22.239  40.108  43.710  46.128
# 2  0.33739  ...  54.075  24.669  61.585  22.191  40.030  39.480  44.121
# 3  0.33664  ...  54.117  24.595  61.561  21.959  40.121  32.848  45.858
# 4  0.32521  ...  53.906  24.451  61.388  22.271  39.538  36.682  45.753
#
#        49      50      51
# 0  47.594  41.384  18.905
# 1  47.508  41.658  18.976
# 2  47.612  41.721  16.562
# 3  47.459  40.836  20.094
# 4  47.458  41.727  18.330
#
# [5 rows x 52 columns]

# %%
namepath = 'https://github.com/waterboy96/TEPData/blob/main/TEPnames.xlsx?raw=true'

# %%
names = pd.read_excel(namepath, index_col = [0], header = None); names.head()
# Out:
#                  1           2           3             4             5   \
# 0
# Type     Continuous  Continuous  Continuous    Continuous    Continuous
# Subtype  Continuous  Continuous  Continuous    Continuous    Continuous
# Block          Feed        Feed        Feed          Feed          Feed
# Name         A Feed      D Feed      E Feed  A and C feed  Recycle flow
#
#                         6                 7               8   \
# 0
# Type            Continuous        Continuous      Continuous
# Subtype         Continuous        Continuous      Continuous
# Block                 Feed           Reactor         Reactor
# Name     Reactor feed rate  Reactor pressure  Reactor level
#
#                           9           10  ...           43                 44  \
# 0                                         ...
# Type              Continuous  Continuous  ...  Manipulated        Manipulated
# Subtype           Continuous  Continuous  ...  Manipulated        Manipulated
# Block                Reactor   Separator  ...         Feed               Feed
# Name     Reactor temperature  Purge rate  ...  A feed flow  A and C feed flow
#
#                                45           46                         47  \
# 0
# Type                  Manipulated  Manipulated                Manipulated
# Subtype               Manipulated  Manipulated                Manipulated
# Block                  Compressor    Separator                  Separator
# Name     Compressor recycle valve  Purge valve  Separator pot liquid flow
#
#                                    48                    49  \
# 0
# Type                      Manipulated           Manipulated
# Subtype                   Manipulated           Manipulated
# Block                        Stripper              Stripper
# Name     Stripper liquid product flow  Stripper steam valve
#
#                                  50                             51  \
# 0
# Type                    Manipulated                    Manipulated
# Subtype                 Manipulated                    Manipulated
# Block                       Reactor                       Stripper
# Name     Reactor cooling water flow  Condenser cooling water flow
#
#                      52
# 0
# Type        Manipulated
# Subtype     Manipulated
# Block           Reactor
# Name     Agitator speed
#
# [4 rows x 52 columns]

# %%
TEP.columns = names.loc['Name']; TEP.head()
# Out:
# Name   A Feed  D Feed  E Feed  A and C feed  Recycle flow  Reactor feed rate  \
# 0     0.24889  3702.3  4502.7        9.4170        26.996             42.183
# 1     0.24904  3666.2  4526.0        9.2682        26.710             42.332
# 2     0.25034  3673.3  4501.3        9.4212        26.842             42.360
# 3     0.25109  3657.8  4497.8        9.3792        26.528             41.982
# 4     0.24563  3698.0  4537.4        9.3746        26.736             42.354
#
# Name  Reactor pressure  Reactor level   Reactor temperature  Purge rate  ...  \
# 0               2705.2          75.173               120.40     0.33611  ...
# 1               2705.5          74.411               120.41     0.33676  ...
# 2               2705.3          75.125               120.41     0.33739  ...
# 3               2707.3          73.992               120.38     0.33664  ...
# 4               2705.3          75.283               120.42     0.32521  ...
#
# Name  A feed flow  A and C feed flow  Compressor recycle valve  Purge valve  \
# 0          54.059             24.804                    63.269       21.950
# 1          53.781             24.790                    62.171       22.239
# 2          54.075             24.669                    61.585       22.191
# 3          54.117             24.595                    61.561       21.959
# 4          53.906             24.451                    61.388       22.271
#
# Name  Separator pot liquid flow  Stripper liquid product flow  \
# 0                        40.188                        39.461
# 1                        40.108                        43.710
# 2                        40.030                        39.480
# 3                        40.121                        32.848
# 4                        39.538                        36.682
#
# Name  Stripper steam valve  Reactor cooling water flow  \
# 0                   47.000                      47.594
# 1                   46.128                      47.508
# 2                   44.121                      47.612
# 3                   45.858                      47.459
# 4                   45.753                      47.458
#
# Name  Condenser cooling water flow   Agitator speed
# 0                            41.384          18.905
# 1                            41.658          18.976
# 2                            41.721          16.562
# 3                            40.836          20.094
# 4                            41.727          18.330
#
# [5 rows x 52 columns]

# %%
#| export
def GetTEP():
    filepath = 'https://github.com/waterboy96/TEPData/blob/1ac08a54cb9d420ff4bc0c3f0076ca06dc2ec7e4/TEP.csv?raw=true'
    TEP = pd.read_csv(filepath, index_col = [0])
    namepath = 'https://github.com/waterboy96/TEPData/blob/main/TEPnames.xlsx?raw=true'
    names = pd.read_excel(namepath, index_col = [0], header = None)
    TEP.columns = names.loc['Name']
    
    return TEP

# %%
TEP = GetTEP()

# %%
TEP
# Out:
# Name   A Feed  D Feed  E Feed  A and C feed  Recycle flow  Reactor feed rate  \
# 0     0.24889  3702.3  4502.7        9.4170        26.996             42.183
# 1     0.24904  3666.2  4526.0        9.2682        26.710             42.332
# 2     0.25034  3673.3  4501.3        9.4212        26.842             42.360
# 3     0.25109  3657.8  4497.8        9.3792        26.528             41.982
# 4     0.24563  3698.0  4537.4        9.3746        26.736             42.354
# ..        ...     ...     ...           ...           ...                ...
# 955   0.23955  3687.2  4581.0        9.3941        26.878             42.199
# 956   0.23352  3625.4  4500.9        9.3884        26.754             42.477
# 957   0.23440  3660.3  4535.7        9.3709        27.034             42.302
# 958   0.23611  3645.0  4506.9        9.1996        26.769             42.252
# 959   0.23729  3666.8  4511.1        9.2764        26.467             42.330
#
# Name  Reactor pressure  Reactor level   Reactor temperature  Purge rate  ...  \
# 0               2705.2          75.173               120.40     0.33611  ...
# 1               2705.5          74.411               120.41     0.33676  ...
# 2               2705.3          75.125               120.41     0.33739  ...
# 3               2707.3          73.992               120.38     0.33664  ...
# 4               2705.3          75.283               120.42     0.32521  ...
# ..                 ...             ...                  ...         ...  ...
# 955             2705.2          75.573               120.41     0.33658  ...
# 956             2708.3          74.372               120.41     0.33708  ...
# 957             2707.3          75.292               120.40     0.34096  ...
# 958             2704.2          74.956               120.38     0.35081  ...
# 959             2702.0          75.270               120.41     0.34809  ...
#
# Name  A feed flow  A and C feed flow  Compressor recycle valve  Purge valve  \
# 0          54.059             24.804                    63.269       21.950
# 1          53.781             24.790                    62.171       22.239
# 2          54.075             24.669                    61.585       22.191
# 3          54.117             24.595                    61.561       21.959
# 4          53.906             24.451                    61.388       22.271
# ..            ...                ...                       ...          ...
# 955        54.571             24.129                    62.237       22.005
# 956        54.741             23.006                    58.477       22.337
# 957        54.324             22.919                    61.946       22.227
# 958        53.732             23.630                    62.816       21.982
# 959        53.682             23.514                    60.518       21.642
#
# Name  Separator pot liquid flow  Stripper liquid product flow  \
# 0                        40.188                        39.461
# 1                        40.108                        43.710
# 2                        40.030                        39.480
# 3                        40.121                        32.848
# 4                        39.538                        36.682
# ..                          ...                           ...
# 955                      41.145                        38.419
# 956                      40.351                        38.657
# 957                      39.877                        41.288
# 958                      41.638                        42.218
# 959                      41.970                        34.258
#
# Name  Stripper steam valve  Reactor cooling water flow  \
# 0                   47.000                      47.594
# 1                   46.128                      47.508
# 2                   44.121                      47.612
# 3                   45.858                      47.459
# 4                   45.753                      47.458
# ..                     ...                         ...
# 955                 45.451                      47.510
# 956                 47.279                      47.567
# 957                 44.007                      47.338
# 958                 40.647                      47.266
# 959                 41.110                      47.165
#
# Name  Condenser cooling water flow   Agitator speed
# 0                            41.384          18.905
# 1                            41.658          18.976
# 2                            41.721          16.562
# 3                            40.836          20.094
# 4                            41.727          18.330
# ..                              ...             ...
# 955                          41.466          16.998
# 956                          40.971          15.621
# 957                          41.891          21.744
# 958                          39.813          18.826
# 959                          40.500          18.353
#
# [960 rows x 52 columns]

# %%
#| hide
import nbdev; nbdev.nbdev_export()
